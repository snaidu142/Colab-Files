# %% [markdown]
# <a href="https://colab.research.google.com/github/snaidu142/Colab-Files/blob/main/Recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Write a function cumulative_sum that accepts an integer parameter n and returns the sum of the numbers 1 through n, including n.
#For example:
#Call                Returns
#cumulative_sum(1)   1
#cumulative_sum(5)   15
def cumsum(n):
  sum = 0
  for i in range(n+1):
    sum += i
  return sum
def cumsum2(n):
  if n == 0:
    return 0
  else:
    return cumsum2(n-1) + n


#cs(5) = cs(4)+5
#cs(4) = cs(3)+4
#cs(3) = cs(2)+3
#cs(2) = cs(1)+2
#cs(1) = 1
#cs(2) = 3
#cs(3) = 6
#cs(4) = 10
#cs(5) = 15

def countitem(a,b):
  return a.count(b)

def countitem2(a,b):
  if not a:
    return 0
  elif a[0] ==b:
    return 1+countitem2(a[1:])
  else:
    return countitem2(a[1:])
def stringlength(a,b):
  sum = 0
  for i in a:
    if len(i) == b:
      sum += 1
def stringlength2(a,b):
  if not a:
    return 0
  elif len(a[0]) ==b:
    return 1 + stringlength2(a[1:])
  else:
    return stringlength(a[1:])

def starsearch(n):
  a = '*'
  for i in range(n):
    a *= 2
    return a
def starsearch2(n):
  if n == 0:
    return '*'
  else:
    return starsearch2(n-1) *2
# Out:
#   File "/tmp/ipykernel_11012/275731418.py", line 52
#     a = *
#          ^
# SyntaxError: invalid syntax
